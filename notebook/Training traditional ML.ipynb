# %%
import os
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from datetime import datetime
import time

# %%
DATA_DIR =  "/content/drive/MyDrive/UTSA Student/Spring 2024/EE5423 HW4ML/Project/dataset"
KEY2DATADIR = {
    'MNIST-2': "./MNIST-2",
    "Fashion-MNIST-2": "./Fashion-MNIST-2",
    "Fashion-MNIST-3": "./Fashion-MNIST-3",
    "Syn-Dataset-4": "./Syn-Dataset-4",
    # "Syn-Dataset-16": "./Syn-Dataset-16"
}
KEY2FULLDIR = {
    'MNIST-2': os.path.join(DATA_DIR, KEY2DATADIR['MNIST-2']),
    'Fashion-MNIST-2': os.path.join(DATA_DIR, KEY2DATADIR['Fashion-MNIST-2']),
    'Fashion-MNIST-3': os.path.join(DATA_DIR, KEY2DATADIR['Fashion-MNIST-3']),
    'Syn-Dataset-4': os.path.join(DATA_DIR, KEY2DATADIR['Syn-Dataset-4']),
    # 'Syn-Dataset-16': os.path.join(DATA_DIR, KEY2DATADIR['Syn-Dataset-16'])
}

# %%
def load_dataset(data_dir: str):
    x_train_file = os.path.join(data_dir, './x_train.npy')
    y_train_file = os.path.join(data_dir, './y_train.npy')
    x_test_file = os.path.join(data_dir, './x_test.npy')
    y_test_file = os.path.join(data_dir, './y_test.npy')

    x_train = np.load(x_train_file)
    y_train = np.load(y_train_file)
    x_test = np.load(x_test_file)
    y_test = np.load(y_test_file)

    return x_train, x_test, y_train, y_test

# %% [markdown]
# ## MNIST-2

# %%
os.path.exists(KEY2FULLDIR['MNIST-2'])
# Out:
# True

# %%
DATA_NAME = "MNIST-2"
DATA_DIR = KEY2FULLDIR[DATA_NAME]

# %%
x_train, x_test, y_train, y_test = load_dataset(DATA_DIR)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (90, 2, 2)
# (10, 2, 2)
# (90,)
# (10,)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1]*x_test.shape[2])

print(x_train.shape)
print(x_test.shape)
# Out:
# (90, 4)
# (10, 4)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes_model = GaussianNB()

# %%
s_time = time.time()
naive_bayes_model.fit(x_train, y_train)
mnist2_naive_bayes_train_time = time.time() - s_time

# %%
mnist2_naive_bayes_train_score = naive_bayes_model.score(x_train, y_train)
print("Naive Bayes's training score: {}".format(mnist2_naive_bayes_train_score))
# Out:
# Naive Bayes's training score: 0.7444444444444445

# %%
mnist2_naive_bayes_test_score = naive_bayes_model.score(x_test, y_test)
print("Naive Bayes's testing score: {}".format(mnist2_naive_bayes_test_score))
# Out:
# Naive Bayes's testing score: 0.7

# %%
print("Naive Bayes's training time: {} (seconds)".format(mnist2_naive_bayes_train_time))
# Out:
# Naive Bayes's training time: 0.003495454788208008 (seconds)

# %% [markdown]
# ### SVMs

# %%
svc_model = SVC()

# %%
s_time = time.time()
svc_model.fit(x_train, y_train)
mnist2_svm_train_time = time.time() - s_time

# %%
mnist2_svm_train_score = svc_model.score(x_train, y_train)
print("SVM's training score: {}".format(mnist2_svm_train_score))
# Out:
# SVM's training score: 0.7444444444444445

# %%
mnist2_svm_test_score = svc_model.score(x_test, y_test)
print("SVM's testing score: {}".format(mnist2_svm_test_score))
# Out:
# SVM's testing score: 0.8

# %%
print("SVM's training time: {} (seconds)".format(mnist2_svm_train_time))
# Out:
# SVM's training time: 0.002725362777709961 (seconds)

# %% [markdown]
# ## Fashion-MNIST-2

# %%
DATA_NAME = "Fashion-MNIST-2"
os.path.exists(KEY2FULLDIR['Fashion-MNIST-2'])
DATA_DIR = KEY2FULLDIR[DATA_NAME]

# %%
x_train, x_test, y_train, y_test = load_dataset(DATA_DIR)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (90, 2, 2)
# (10, 2, 2)
# (90,)
# (10,)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1]*x_test.shape[2])

print(x_train.shape)
print(x_test.shape)
# Out:
# (90, 4)
# (10, 4)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes_model = GaussianNB()

# %%
s_time = time.time()
naive_bayes_model.fit(x_train, y_train)
fashionmnist2_naive_bayes_train_time = time.time() - s_time

# %%
fashionmnist2_naive_bayes_train_score = naive_bayes_model.score(x_train, y_train)
print("Naive Bayes's training score: {}".format(fashionmnist2_naive_bayes_train_score))
# Out:
# Naive Bayes's training score: 0.7666666666666667

# %%
fashionmnist2_naive_bayes_test_score = naive_bayes_model.score(x_test, y_test)
print("Naive Bayes's testing score: {}".format(fashionmnist2_naive_bayes_test_score))
# Out:
# Naive Bayes's testing score: 0.8

# %%
print("Naive Bayes's training time: {} (seconds)".format(fashionmnist2_naive_bayes_train_time))
# Out:
# Naive Bayes's training time: 0.002870798110961914 (seconds)

# %% [markdown]
# ### SVMs

# %%
svc_model = SVC()

# %%
s_time = time.time()
svc_model.fit(x_train, y_train)
fashionmnist2_svm_train_time = time.time() - s_time

# %%
fashionmnist2_svm_train_score = svc_model.score(x_train, y_train)
print("SVM's training score: {}".format(fashionmnist2_svm_train_score))
# Out:
# SVM's training score: 0.8777777777777778

# %%
fashionmnist2_svm_test_score = svc_model.score(x_test, y_test)
print("SVM's testing score: {}".format(fashionmnist2_svm_test_score))
# Out:
# SVM's testing score: 1.0

# %%
print("SVM's training time: {} (seconds)".format(fashionmnist2_svm_train_time))
# Out:
# SVM's training time: 0.0022614002227783203 (seconds)

# %% [markdown]
# ## Fashion-MNIST-3

# %%
DATA_NAME = "Fashion-MNIST-3"
os.path.exists(KEY2FULLDIR['Fashion-MNIST-3'])
DATA_DIR = KEY2FULLDIR[DATA_NAME]

# %%
x_train, x_test, y_train, y_test = load_dataset(DATA_DIR)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-c9f674c57e62> in <cell line: 1>()
# ----> 1 x_train, x_test, y_train, y_test, x, y = load_dataset(DATA_DIR)
#       2
#       3 print(x_train.shape)
#       4 print(x_test.shape)
#       5 print(y_train.shape)
#
# ValueError: not enough values to unpack (expected 6, got 4)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1]*x_test.shape[2])

print(x_train.shape)
print(x_test.shape)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes_model = GaussianNB()

# %%
s_time = time.time()
naive_bayes_model.fit(x_train, y_train)
fashionmnist3_naive_bayes_train_time = time.time() - s_time

# %%
fashionmnist3_naive_bayes_train_score = naive_bayes_model.score(x_train, y_train)
print("Naive Bayes's training score: {}".format(fashionmnist3_naive_bayes_train_score))

# %%
fashionmnist3_naive_bayes_test_score = naive_bayes_model.score(x_test, y_test)
print("Naive Bayes's testing score: {}".format(fashionmnist3_naive_bayes_test_score))

# %%
print("Naive Bayes's training time: {} (seconds)".format(fashionmnist3_naive_bayes_train_time))

# %% [markdown]
# ### SVMs

# %%
svc_model = SVC()

# %%
s_time = time.time()
svc_model.fit(x_train, y_train)
fashionmnist3_svm_train_time = time.time() - s_time

# %%
fashionmnist3_svm_train_score = svc_model.score(x_train, y_train)
print("SVM's training score: {}".format(fashionmnist3_svm_train_score))

# %%
fashionmnist3_svm_test_score = svc_model.score(x_test, y_test)
print("SVM's testing score: {}".format(fashionmnist3_svm_test_score))

# %%
print("SVM's training time: {} (seconds)".format(fashionmnist3_svm_train_time))

# %% [markdown]
# ## Synthetic-4

# %%
DATA_NAME = "Syn-Dataset-4"
print(os.path.exists(KEY2FULLDIR[DATA_NAME]))
DATA_DIR = KEY2FULLDIR[DATA_NAME]

# %%
x_train, x_test, y_train, y_test = load_dataset(DATA_DIR)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes_model = GaussianNB()

# %%
s_time = time.time()
naive_bayes_model.fit(x_train, y_train)
synthetic4_naive_bayes_train_time = time.time() - s_time

# %%
synthetic4_naive_bayes_train_score = naive_bayes_model.score(x_train, y_train)
print("Naive Bayes's training score: {}".format(synthetic4_naive_bayes_train_score))

# %%
synthetic4_naive_bayes_test_score = naive_bayes_model.score(x_test, y_test)
print("Naive Bayes's testing score: {}".format(synthetic4_naive_bayes_test_score))

# %%
print("Naive Bayes's training time: {} (seconds)".format(synthetic4_naive_bayes_train_time))

# %% [markdown]
# ### SVMs

# %%
svc_model = SVC()

# %%
s_time = time.time()
svc_model.fit(x_train, y_train)
synthetic4_svm_train_time = time.time() - s_time

# %%
synthetic4_svm_train_score = svc_model.score(x_train, y_train)
print("SVM's training score: {}".format(synthetic4_svm_train_score))

# %%
synthetic4_svm_test_score = svc_model.score(x_test, y_test)
print("SVM's testing score: {}".format(synthetic4_svm_test_score))

# %%
print("SVM's training time: {} (seconds)".format(synthetic4_svm_train_time))

# %% [markdown]
# ## Synthetic-16

# %%
DATA_NAME = "Syn-Dataset-16"
print(os.path.exists(KEY2FULLDIR[DATA_NAME]))
DATA_DIR = KEY2FULLDIR[DATA_NAME]

# %%
x_train, x_test, y_train, y_test, x, y = load_dataset(DATA_DIR)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes_model = GaussianNB()

# %%
s_time = time.time()
naive_bayes_model.fit(x_train, y_train)
synthetic16_naive_bayes_train_time = time.time() - s_time

# %%
synthetic16_naive_bayes_train_score = naive_bayes_model.score(x_train, y_train)
print("Naive Bayes's training score: {}".format(synthetic16_naive_bayes_train_score))

# %%
synthetic16_naive_bayes_test_score = naive_bayes_model.score(x_test, y_test)
print("Naive Bayes's testing score: {}".format(synthetic16_naive_bayes_test_score))

# %%
print("Naive Bayes's training time: {} (seconds)".format(synthetic16_naive_bayes_train_time))

# %% [markdown]
# ### SVMs

# %%
svc_model = SVC()

# %%
s_time = time.time()
svc_model.fit(x_train, y_train)
synthetic16_svm_train_time = time.time() - s_time

# %%
synthetic16_svm_train_score = svc_model.score(x_train, y_train)
print("SVM's training score: {}".format(synthetic16_svm_train_score))

# %%
synthetic16_svm_test_score = svc_model.score(x_test, y_test)
print("SVM's testing score: {}".format(synthetic16_svm_test_score))

# %%
print("SVM's training time: {} (seconds)".format(synthetic16_svm_train_time))

# %% [markdown]
# ## Store the results

# %%
# prompt: print the results as data frames also include the running time with the columns as different dataset and rows as different metrics. Make sure the output follows each column is one dataset

import pandas as pd

# Create a dictionary to store the results
results_dict = {
    'Dataset': ['MNIST-2', 'Fashion-MNIST-2', 'Fashion-MNIST-3', 'Synthetic-4'],
    'Naive Bayes Training Score': [mnist2_naive_bayes_train_score, fashionmnist2_naive_bayes_train_score, fashionmnist3_naive_bayes_train_score, synthetic4_naive_bayes_train_score, synthetic16_naive_bayes_train_score],
    'Naive Bayes Testing Score': [mnist2_naive_bayes_test_score, fashionmnist2_naive_bayes_test_score, fashionmnist3_naive_bayes_test_score, synthetic4_naive_bayes_test_score, synthetic16_naive_bayes_test_score],
    'Naive Bayes Training Time': [mnist2_naive_bayes_train_time, fashionmnist2_naive_bayes_train_time, fashionmnist3_naive_bayes_train_time, synthetic4_naive_bayes_train_time, synthetic16_naive_bayes_train_time],
    'SVM Training Score': [mnist2_svm_train_score, fashionmnist2_svm_train_score, fashionmnist3_svm_train_score, synthetic4_svm_train_score, synthetic16_svm_train_score],
    'SVM Testing Score': [mnist2_svm_test_score, fashionmnist2_svm_test_score, fashionmnist3_svm_test_score, synthetic4_svm_test_score, synthetic16_svm_test_score],
    'SVM Training Time': [mnist2_svm_train_time, fashionmnist2_svm_train_time, fashionmnist3_svm_train_time, synthetic4_svm_train_time, synthetic16_svm_train_time]
}

# Create a pandas DataFrame from the dictionary
df = pd.DataFrame(results_dict)

# Print the DataFrame
print(df)

# %%
datetime_str = datetime.now().strftime("%d-%m-%Y")
OUTPUT_DIR = "/content/drive/MyDrive/UTSA Student/Spring 2024/EE5423 HW4ML/Project/output/results"
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)
fulloutput_file = os.path.join(OUTPUT_DIR, "{}_traditional_ml_results.csv".format(datetime_str))
df.to_csv(fulloutput_file)
